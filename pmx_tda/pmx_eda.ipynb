# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import persim
from ripser import Rips

# %%
rootpath = os.path.join("C:", os.sep, "Users", "bubba", "Documents", "DataProjects", "tda")

# %%
df = pd.read_csv(os.path.join(rootpath, "predictive-maintenance-dataset.csv"))

# %%
df.columns = ['id', 'revs', 'humid', 'vibe', 'temp', 'pres', 'vol', 'force', 'load']

# %% [markdown]
# # Visualize the revolutions

# %%
plt.figure(figsize=(12,8))
plt.plot(df['id'], df['revs']);

# %% [markdown]
# # Zoom in - looks like increased sampling rate

# %%
zoomed = df.iloc[105000:106000]

# %%
plt.figure(figsize=(12,8))
plt.plot(zoomed['id'], zoomed['revs'])
